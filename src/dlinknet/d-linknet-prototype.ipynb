# %%
github_secret = "GITHUB_PAT"
wandb_secret = "WANDB_KEY"
is_yml = True

# %%
from kaggle_secrets import UserSecretsClient
import os

user_secrets = UserSecretsClient()
github_pat = user_secrets.get_secret(github_secret)
github_user = "instaroad"
repo_name = "InstaRoadPrototype"
branch_name = "dlinknet-prototype" # <-- Define your branch here

# Added -b {branch_name} and --single-branch
cmd_string = f"git clone --recursive -b {branch_name} --single-branch https://oauth2:{github_pat}@github.com/{github_user}/{repo_name}.git"

# %cd /kaggle/working
# !rm -rf /kaggle/working/InstaRoadPrototype
# !git config --global url."https://github.com/".insteadOf git@github.com:
# !{cmd_string}
# Out:
# /kaggle/working
# Cloning into 'InstaRoadPrototype'...
# remote: Enumerating objects: 751, done.
# remote: Counting objects: 100% (303/303), done.
# remote: Compressing objects: 100% (94/94), done.
# remote: Total 751 (delta 239), reused 228 (delta 207), pack-reused 448 (from 1)
# Receiving objects: 100% (751/751), 1.38 MiB | 6.85 MiB/s, done.
# Resolving deltas: 100% (445/445), done.
# Submodule 'instageo' (https://github.com/InstaRoad/InstaGeo.git) registered for path 'instageo'
# Submodule 'sam_road' (https://github.com/InstaRoad/samroad.git) registered for path 'sam_road'
# Cloning into '/kaggle/working/InstaRoadPrototype/instageo'...
# remote: Enumerating objects: 2065, done.
# remote: Counting objects: 100% (368/368), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 2065 (delta 329), reused 320 (delta 319), pack-reused 1697 (from 1)
# Receiving objects: 100% (2065/2065), 11.39 MiB | 21.40 MiB/s, done.
# Resolving deltas: 100% (1354/1354), done.
# ...

# %%
# !/kaggle/working/InstaRoadPrototype/src/dlinknet/prep/prep_env.bash
# Out:
# Installing python dependencies...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.3/25.3 MB 42.2 MB/s eta 0:00:0000:0100:01
# ...
# Using Python 3.12.13 environment at: /usr
# Resolved 140 packages in 13.69s
# Prepared 27 packages in 2.11s
# Uninstalled 2 packages in 63ms
# Installed 27 packages in 63ms
#  + aenum==3.1.17
#  + ghp-import==2.1.0
#  + griffelib==2.1.0
#  + hydra-core==1.3.3
#  + instaroadprototype==0.1.0 (from file:///kaggle/working/InstaRoadPrototype)
#  + jsonargparse==4.49.0
#  + lightly==1.5.22
#  + lightly-utils==0.0.2
#  + lightning==2.6.5
#  - matplotlib==3.10.0
#  + matplotlib==3.11.0
#  + mergedeep==1.3.4
#  + mkdocs==1.6.1
#  + mkdocs-autorefs==1.4.4
#  + mkdocs-gen-files==0.6.1
#  + mkdocs-get-deps==0.2.2
#  + mkdocs-literate-nav==0.6.3
#  + mkdocstrings==1.0.4
#  + mkdocstrings-python==2.0.5
#  + properdocs==1.6.7
#  + pymdown-extensions==11.0
#  + pyyaml-env-tag==1.1
#  + rioxarray==0.22.0
#  + segmentation-models-pytorch==0.5.0
# ...

# %%
import os
import wandb
from kaggle_secrets import UserSecretsClient

user_secrets = UserSecretsClient()
wandb_api_key = user_secrets.get_secret(wandb_secret)

os.environ["WANDB_API_KEY"] = wandb_api_key
wandb.login(key=wandb_api_key)
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: catherinelee2004 (models-university-of-cape-town) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
# %cd /kaggle/working/InstaRoadPrototype/
import src.utils.lightning_utils
import src.utils.lightning_dataset
print("All imports OK")
# Out:
# /kaggle/working/InstaRoadPrototype
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_58/642916684.py in <cell line: 0>()
#       1 get_ipython().run_line_magic('cd', '/kaggle/working/InstaRoadPrototype/')
# ----> 2 import src.utils.lightning_utils
#       3 import src.utils.lightning_dataset
#       4 print("All imports OK")
#
# /kaggle/working/InstaRoadPrototype/src/utils/lightning_utils.py in <module>
#       1 import os
# ----> 2 import torch
#       3 import lightning as L  # pip install lightning  (formerly pytorch-lightning)
#       4 import segmentation_models_pytorch as smp
#       5 import torchmetrics  # pip install torchmetrics (ships with lightning, but pin if needed)
#
# /usr/local/lib/python3.12/dist-packages/torch/__init__.py in <module>
#    2245 )
#    2246
# -> 2247 from torch import (
#    2248     __config__ as __config__,
# ...

# %%
if is_yml:
    # !ls
    # !python src/utils/cli_main.py fit --config src/dlinknet/train.yaml
else:
    # %cd /kaggle/working/InstaRoadPrototype/src/dlinknet/
    # !python train.py
# Out:
# /kaggle/working/InstaRoadPrototype
# dataset     docs      mkdocs.yml      README.md  scripts  uv.lock
# Dockerfile  instageo  pyproject.toml  sam_road	 src
# usage: cli_main.py [options] fit [-c CONFIG]
#                                  [--seed_everything SEED_EVERYTHING]
#                                  [--trainer CONFIG]
#                                  [--trainer.accelerator ACCELERATOR]
#                                  [--trainer.strategy STRATEGY]
#                                  [--trainer.devices DEVICES]
#                                  [--trainer.num_nodes NUM_NODES]
#                                  [--trainer.precision PRECISION]
#                                  [--trainer.logger LOGGER]
#                                  [--trainer.callbacks CALLBACKS]
#                                  [--trainer.fast_dev_run FAST_DEV_RUN]
#                                  [--trainer.max_epochs MAX_EPOCHS]
# ...

# %%
# %cd /kaggle/working/InstaRoadPrototype/

if is_yml:
    # !python src/utils/cli_main.py test    --config src/dlinknet/test.yaml
    # !python src/utils/cli_main.py predict --config src/dlinknet/predict.yaml
else:
    # %cd /kaggle/working/InstaRoadPrototype/src/dlinknet/
    # !python inference.py
# Out:
# /kaggle/working/InstaRoadPrototype
# usage: cli_main.py [options] test [-c CONFIG]
#                                   [--seed_everything SEED_EVERYTHING]
#                                   [--trainer CONFIG]
#                                   [--trainer.accelerator ACCELERATOR]
#                                   [--trainer.strategy STRATEGY]
#                                   [--trainer.devices DEVICES]
#                                   [--trainer.num_nodes NUM_NODES]
#                                   [--trainer.precision PRECISION]
#                                   [--trainer.logger LOGGER]
#                                   [--trainer.callbacks CALLBACKS]
#                                   [--trainer.fast_dev_run FAST_DEV_RUN]
#                                   [--trainer.max_epochs MAX_EPOCHS]
#                                   [--trainer.min_epochs MIN_EPOCHS]
#                                   [--trainer.max_steps MAX_STEPS]
# ...
