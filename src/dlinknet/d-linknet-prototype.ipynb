# %%
github_secret = "GITHUB_PAT"
wandb_secret = "WANDB_KEY"

github_user = "instaroad"
repo_name = "InstaRoadPrototype"
branch_name = "dlinknet-prototype"

is_yml = True

# %%
from kaggle_secrets import UserSecretsClient
import os
import wandb

user_secrets = UserSecretsClient()
github_pat = user_secrets.get_secret(github_secret)

wandb_api_key = user_secrets.get_secret(wandb_secret)
os.environ["WANDB_API_KEY"] = wandb_api_key
wandb.login(key=wandb_api_key)
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: catherinelee2004 (models-university-of-cape-town) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
cmd_string = f"git clone --recursive -b {branch_name} --single-branch https://oauth2:{github_pat}@github.com/{github_user}/{repo_name}.git"

# %cd /kaggle/working
# !rm -rf /kaggle/working/InstaRoadPrototype
# !git config --global url."https://github.com/".insteadOf git@github.com:
# !{cmd_string}
# Out:
# /kaggle/working
# Cloning into 'InstaRoadPrototype'...
# remote: Enumerating objects: 870, done.
# remote: Counting objects: 100% (345/345), done.
# remote: Compressing objects: 100% (120/120), done.
# remote: Total 870 (delta 273), reused 249 (delta 223), pack-reused 525 (from 1)
# Receiving objects: 100% (870/870), 1.47 MiB | 12.23 MiB/s, done.
# Resolving deltas: 100% (523/523), done.
# Submodule 'instageo' (https://github.com/InstaRoad/InstaGeo.git) registered for path 'instageo'
# Submodule 'sam_road' (https://github.com/InstaRoad/samroad.git) registered for path 'sam_road'
# Cloning into '/kaggle/working/InstaRoadPrototype/instageo'...
# remote: Enumerating objects: 2065, done.
# remote: Counting objects: 100% (574/574), done.
# remote: Compressing objects: 100% (102/102), done.
# remote: Total 2065 (delta 507), reused 473 (delta 472), pack-reused 1491 (from 1)
# Receiving objects: 100% (2065/2065), 11.42 MiB | 17.64 MiB/s, done.
# Resolving deltas: 100% (1334/1334), done.
# Cloning into '/kaggle/working/InstaRoadPrototype/sam_road'...
# remote: Enumerating objects: 379, done.
# remote: Counting objects: 100% (239/239), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 379 (delta 207), reused 196 (delta 196), pack-reused 140 (from 1)
# Receiving objects: 100% (379/379), 3.17 MiB | 25.37 MiB/s, done.
# Resolving deltas: 100% (253/253), done.
# Submodule path 'instageo': checked out '2926e25c3cbc4e48c6b43f9107d954f83b0eec2b'
# Submodule path 'sam_road': checked out '6e53f64d6a1d4f2d7e317341b6eb1d5747768ec0'
# Submodule 'sam' (git@github.com:htcr/segment-anything-road.git) registered for path 'sam_road/sam'
# Submodule 'segment-anything-road' (git@github.com:htcr/segment-anything-road.git) registered for path 'sam_road/segment-anything-road'
# Cloning into '/kaggle/working/InstaRoadPrototype/sam_road/sam'...
# remote: Enumerating objects: 289, done.
# remote: Total 289 (delta 0), reused 0 (delta 0), pack-reused 289 (from 1)
# Receiving objects: 100% (289/289), 18.30 MiB | 17.58 MiB/s, done.
# Resolving deltas: 100% (148/148), done.
# Cloning into '/kaggle/working/InstaRoadPrototype/sam_road/segment-anything-road'...
# remote: Enumerating objects: 289, done.
# remote: Total 289 (delta 0), reused 0 (delta 0), pack-reused 289 (from 1)
# Receiving objects: 100% (289/289), 18.30 MiB | 35.50 MiB/s, done.
# Resolving deltas: 100% (148/148), done.
# Submodule path 'sam_road/sam': checked out '6fdee8f2727f4506cfbbe553e23b895e27956588'
# Submodule path 'sam_road/segment-anything-road': checked out '6fdee8f2727f4506cfbbe553e23b895e27956588'

# %%
# !/kaggle/working/InstaRoadPrototype/src/dlinknet/prep/prep_env.bash
# Out:
# Installing python dependencies...
# Collecting uv
#   Downloading uv-0.11.24-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Downloading uv-0.11.24-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.3/25.3 MB 67.4 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: uv
# Successfully installed uv-0.11.24
# Using Python 3.12.13 environment at: /usr
# Resolved 158 packages in 10.61s
# Prepared 28 packages in 2.12s
# Uninstalled 3 packages in 80ms
# Installed 28 packages in 76ms
#  + aenum==3.1.17
#  - cuda-bindings==13.2.0
#  + cuda-bindings==12.9.4
#  + ghp-import==2.1.0
#  + griffelib==2.1.0
#  + hydra-core==1.3.3
#  + instaroadprototype==0.1.0 (from file:///kaggle/working/InstaRoadPrototype)
#  + jsonargparse==4.49.0
#  + lightly==1.5.22
#  + lightly-utils==0.0.2
#  + lightning==2.6.5
#  - matplotlib==3.10.0
#  + matplotlib==3.11.0
#  + mergedeep==1.3.4
#  + mkdocs==1.6.1
#  + mkdocs-autorefs==1.4.4
#  + mkdocs-gen-files==0.6.1
#  + mkdocs-get-deps==0.2.2
#  + mkdocs-literate-nav==0.6.3
#  + mkdocstrings==1.0.4
#  + mkdocstrings-python==2.0.5
#  + properdocs==1.6.7
#  + pymdown-extensions==11.0
#  + pyyaml-env-tag==1.1
#  + rioxarray==0.22.0
#  + segmentation-models-pytorch==0.5.0
#  + terratorch==1.2.8 (from git+https://github.com/terrastackai/terratorch.git@7ed0d148bd7e79f469653c3ac95436ea828964af)
#  + torchgeo==0.9.0
#  + typeshed-client==2.12.0
#  - xarray==2025.12.0
#  + xarray==2026.4.0
# Preparing Kaggle dataset
# Sentinel-2 Roads Dataset Path: /kaggle/input/datasets/sonisuyash/sentinel-2-roads-dataset
# Symlink created at: /kaggle/working/InstaRoadPrototype/dataset/sentinel2/sentinel2_256
# Fetching D-LinkNet architecture source files...
# Cloning into 'DeepGlobe-Road-Extraction-Challenge'...
# remote: Enumerating objects: 25, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 25 (delta 1), reused 16 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (25/25), 2.15 MiB | 19.33 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# Environment ready! D-LinkNet source code added to working directory.

# %%
# %cd /kaggle/working/InstaRoadPrototype/

if is_yml:
    # !ls
    # !python -m src.utils.cli_main fit --config src/dlinknet/train.yaml
else:
    # %cd /kaggle/working/InstaRoadPrototype/src/dlinknet/
    # !python train.py
# Out:
# /kaggle/working/InstaRoadPrototype
# dataset     docs      mkdocs.yml      README.md  scripts  uv.lock
# Dockerfile  instageo  pyproject.toml  sam_road	 src
# Seed set to 42
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
# 100%|███████████████████████████████████████| 83.3M/83.3M [00:00<00:00, 190MB/s]
# [{'class_path': 'albumentations.Resize', 'init_args': {'height': 1024, 'width': 1024}}, {'class_path': 'albumentations.Normalize', 'init_args': {'mean': [0.485, 0.456, 0.406], 'std': [0.229, 0.224, 0.225]}}]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/2
# [rank: 1] Seed set to 42
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# [{'class_path': 'albumentations.Resize', 'init_args': {'height': 1024, 'width': 1024}}, {'class_path': 'albumentations.Normalize', 'init_args': {'mean': [0.485, 0.456, 0.406], 'std': [0.229, 0.224, 0.225]}}]
# Initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/2
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 2 processes
# ----------------------------------------------------------------------------------------------------
#
# wandb: WARNING The anonymous setting has no effect and will be removed in a future version.
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# wandb: Currently logged in as: catherinelee2004 (models-university-of-cape-town) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.25.1
# wandb: Run data is saved locally in wandb/run-20260625_143227-q1y3nvj9
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run celestial-thunder-20
# wandb: ⭐️ View project at https://wandb.ai/models-university-of-cape-town/dlinknet_sentinel2_baseline
# wandb: 🚀 View run at https://wandb.ai/models-university-of-cape-town/dlinknet_sentinel2_baseline/runs/q1y3nvj9
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1]
# ┏━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name           ┃ Type               ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ model          │ DinkNet34          │ 31.1 M │ train │     0 │
# │ 1 │ criterion      │ DiceLoss           │      0 │ train │     0 │
# │ 2 │ test_iou       │ BinaryJaccardIndex │      0 │ train │     0 │
# │ 3 │ test_f1        │ BinaryF1Score      │      0 │ train │     0 │
# │ 4 │ test_precision │ BinaryPrecision    │      0 │ train │     0 │
# │ 5 │ test_recall    │ BinaryRecall       │      0 │ train │     0 │
# │ 6 │ test_accuracy  │ BinaryAccuracy     │      0 │ train │     0 │
# └───┴────────────────┴────────────────────┴────────┴───────┴───────┘
# Trainable params: 31.1 M
# Non-trainable params: 0
# Total params: 31.1 M
# Total estimated model params size (MB): 124.385
# Modules in train mode: 156
# Modules in eval mode: 0
# Total FLOPs: 0
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/_pytree.py:2
# 1: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec,
# TreeSpec) and treespec.is_leaf()` instead.
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/connectors/log0:00:02 • -:--:-- 0.00it/s
# ger_connector/result.py:433: It is recommended to use `self.log('val_loss', ...,
# sync_dist=True)` when logging on epoch level in distributed setting to
# accumulate the metric across devices.
# Epoch 0/4  ━━━━━━━━━━━━━━━━━ 0/493 0:00:00 • -:--:-- 0.00it/s v_num: nvj9
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py:865:
# UserWarning: The AccumulateGrad node's stream does not match the stream of the
# node that produced the incoming gradient. This may incur unnecessary
# synchronization and break CUDA graph capture if the AccumulateGrad node's stream
# is the default stream. This mismatch is caused by an AccumulateGrad node created
# prior to the current iteration being kept alive. This can happen if the autograd
# graph is still being kept alive by tensors such as the loss, or if you are using
# DDP, which will stash a reference to the node. To resolve the mismatch, delete
# all references to the autograd graph or ensure that DDP initialization is
# performed under the same stream as subsequent forwards. If the mismatch is
# intentional, you can use
# torch.autograd.graph.set_warn_on_accumulate_grad_stream_mismatch(False) to
# suppress this warning. (Triggered internally at
# /pytorch/torch/csrc/autograd/input_buffer.cpp:240.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine
# to run the backward pass
# Epoch 0/4  ━━━━━━━━━━━━━━━━━ 0/493 0:00:00 • -:--:-- 0.00it/s v_num: nvj9
#                                                               val_loss: 0.990   /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py:865: UserWarning: The AccumulateGrad node's stream does not match the stream of the node that produced the incoming gradient. This may incur unnecessary synchronization and break CUDA graph capture if the AccumulateGrad node's stream is the default stream. This mismatch is caused by an AccumulateGrad node created prior to the current iteration being kept alive. This can happen if the autograd graph is still being kept alive by tensors such as the loss, or if you are using DDP, which will stash a reference to the node. To resolve the mismatch, delete all references to the autograd graph or ensure that DDP initialization is performed under the same stream as subsequent forwards. If the mismatch is intentional, you can use torch.autograd.graph.set_warn_on_accumulate_grad_stream_mismatch(False) to suppress this warning. (Triggered internally at /pytorch/torch/csrc/autograd/input_buffer.cpp:240.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Epoch 0/4  ━━━━━━━━━━━━━━━━━━━━━━ 493/493 0:07:53 • 0:00:00 1.03it/s v_num: nvj9 nvj9 nvj9
# Epoch 0/4  ━━━━━━━━━━━━━━━━━━━━━━ 493/493 0:07:53 • 0:00:00 1.03it/s v_num: nvj9
# Epoch 0/4  ━━━━━━━━━━━━━━━━━━━━━━ 493/493 0:07:53 • 0:00:00 1.03it/s v_num: nvj9
# Epoch 0/4  ━━━━━━━━━━━━━━━━━━━━━━ 493/493 0:07:53 • 0:00:00 1.03it/s v_num: nvj9
# Epoch 0/4  ━━━━━━━━━━━━━━━━━━━━━━ 493/493 0:07:53 • 0:00:00 1.03it/s v_num: nvj9
# Epoch 0/4  ━━━━━━━━━━━━━━━━━━━━━━ 493/493 0:07:53 • 0:00:00 1.03it/s v_num: nvj9
# Epoch 0/4  ━━━━━━━━━━━━━━━━━━━━━━ 493/493 0:07:53 • 0:00:00 1.03it/s v_num: nvj9
# Epoch 0/4  ━━━━━━━━━━━━━━━━━━━━━━ 493/493 0:07:53 • 0:00:00 1.03it/s v_num: nvj9
# Epoch 0/4  ━━━━━━━━━━━━━━━━━━━━━━ 493/493 0:07:53 • 0:00:00 1.03it/s v_num: nvj9
# Epoch 0/4  ━━━━━━━━━━━━━━━━━━━━━━ 493/493 0:07:53 • 0:00:00 1.03it/s v_num: nvj9
# Epoch 0/4  ━━━━━━━━━━━━━━━━━━━━━━ 493/493 0:07:53 • 0:00:00 1.03it/s v_num: nvj9
# Epoch 0/4  ━━━━━━━━━━━━━━━━━━━━━━ 493/493 0:07:53 • 0:00:00 1.03it/s v_num: nvj9
# Epoch 0/4  ━━━━━━━━━━━━━━━━━━━━━━ 493/493 0:07:53 • 0:00:00 1.03it/s v_num: nvj9
# Epoch 0/4  ━━━━━━━━━━━━━━━━━━━━━━ 493/493 0:07:53 • 0:00:00 1.03it/s v_num: nvj9
# Epoch 0/4  ━━━━━━━━━━━━━━━━━━━━━━ 493/493 0:07:53 • 0:00:00 1.03it/s v_num: nvj9
# Epoch 0/4  ━━━━━━━━━━━━━━━━━━━━━━ 493/493 0:07:53 • 0:00:00 1.03it/s v_num: nvj9
# Epoch 0/4  ━━━━━━━━━━━━━━━━━━━━━━ 493/493 0:07:53 • 0:00:00 1.03it/s v_num: nvj9
# Epoch 0/4  ━━━━━━━━━━━━━━━━━━━━━━ 493/493 0:07:53 • 0:00:00 1.03it/s v_num: nvj9
# Epoch 0/4  ━━━━━━━━━━━━━━━━━━━━━━ 493/493 0:07:53 • 0:00:00 1.03it/s v_num: nvj9
# Epoch 0/4  ━━━━━━━━━━━━━━━━━━━━━━ 493/493 0:07:53 • 0:00:00 1.03it/s v_num: nvj9
# Epoch 0/4  ━━━━━━━━━━━━━━━━━━━━━━ 493/493 0:07:53 • 0:00:00 1.03it/s v_num: nvj9
# Epoch 0/4  ━━━━━━━━━━━━━━━━━━━━━━ 493/493 0:07:53 • 0:00:00 1.03it/s v_num: nvj9
# Epoch 0/4  ━━━━━━━━━━━━━━━━━━━━━━ 493/493 0:07:53 • 0:00:00 1.03it/s v_num: nvj9
# Epoch 0/4  ━━━━━━━━━━━━━━━━━━━━━━ 493/493 0:07:53 • 0:00:00 1.03it/s v_num: nvj9
# Epoch 0/4  ━━━━━━━━━━━━━━━━━━━━━━ 493/493 0:07:53 • 0:00:00 1.03it/s v_num: nvj9
# Epoch 0/4  ━━━━━━━━━━━━━━━━━━━━━━ 493/493 0:07:53 • 0:00:00 1.03it/s v_num: nvj9
# Epoch 0/4  ━━━━━━━━━━━━━━━━━━━━━━ 493/493 0:07:53 • 0:00:00 1.03it/s v_num: nvj9
# Epoch 0/4  ━━━━━━━━━━━━━━━━ 493/493 0:07:53 • 0:00:00 1.03it/s v_num: nvj9
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/connectors/log
# ger_connector/result.py:433: It is recommended to use `self.log('train_loss',
# ..., sync_dist=True)` when logging on epoch level in distributed setting to
# accumulate the metric across devices.
# Epoch 0/4  ━━━━━━━━━━━━━━━━ 493/493 0:07:53 • 0:00:00 1.03it/s v_num: nvj9
# Epoch 0/4  ━━━━━━━━━━━━━━━━ 493/493 0:07:53 • 0:00:00 1.03it/s v_num: nvj9
#                                                                val_loss: 0.624
# Epoch 1/4  ━━━━━━━━━━━━━━━━━ 0/493 0:00:00 • -:--:-- 0.00it/s v_num: nvj9
#                                                               val_loss: 0.624
# Epoch 1/4  ━━━━━━━━━━━━━━━━━ 0/493 0:00:00 • -:--:-- 0.00it/s v_num: nvj9
#                                                               val_loss: 0.624
# Epoch 1/4  ━━━━━━━━━━━━━━━━━ 1/493 0:00:01 • -:--:-- 0.00it/s v_num: nvj9
#                                                               val_loss: 0.624
# Epoch 1/4  ━━━━━━━━━━━━━━━━━ 2/493 0:00:02 • 0:07:43 1.06it/s v_num: nvj9
#                                                               val_loss: 0.624
# Epoch 1/4  ━━━━━━━━━━━━━━━━━ 3/493 0:00:03 • 0:07:48 1.05it/s v_num: nvj9
#                                                               val_loss: 0.624
# Epoch 1/4  ━━━━━━━━━━━━━━━━━ 4/493 0:00:04 • 0:07:51 1.04it/s v_num: nvj9
#                                                               val_loss: 0.624
# Epoch 1/4  ━━━━━━━━━━━━━━━━━ 5/493 0:00:05 • 0:07:51 1.04it/s v_num: nvj9
#                                                               val_loss: 0.624
# Epoch 1/4  ━━━━━━━━━━━━━━━━━ 6/493 0:00:06 • 0:07:50 1.04it/s v_num: nvj9
#                                                               val_loss: 0.624
# Epoch 1/4  ━━━━━━━━━━━━━━━━━ 7/493 0:00:07 • 0:07:51 1.03it/s v_num: nvj9
#                                                               val_loss: 0.624
# Epoch 1/4  ━━━━━━━━━━━━━━━━━ 8/493 0:00:08 • 0:07:51 1.03it/s v_num: nvj9
#                                                               val_loss: 0.624
# Epoch 1/4  ━━━━━━━━━━━━━━━━━ 9/493 0:00:08 • 0:07:50 1.03it/s v_num: nvj9
#                                                               val_loss: 0.624
# Epoch 1/4  ━━━━━━━━━━━━━━━━━ 10/493 0:00:09 • 0:07:48 1.03it/s v_num: nvj9
#                                                                val_loss: 0.624
# Epoch 1/4  ━━━━━━━━━━━━━━━━━ 11/493 0:00:10 • 0:07:49 1.03it/s v_num: nvj9
#                                                                val_loss: 0.624
# Epoch 1/4  ━━━━━━━━━━━━━━━━━ 12/493 0:00:11 • 0:07:47 1.03it/s v_num: nvj9
#                                                                val_loss: 0.624
# Epoch 1/4  ━━━━━━━━━━━━━━━━━ 13/493 0:00:12 • 0:07:47 1.03it/s v_num: nvj9
#                                                                val_loss: 0.624
# Epoch 1/4  ━━━━━━━━━━━━━━━━━ 14/493 0:00:13 • 0:07:46 1.03it/s v_num: nvj9
#                                                                val_loss: 0.624
# Epoch 1/4  ╸━━━━━━━━━━━━━━━━ 15/493 0:00:14 • 0:07:46 1.03it/s v_num: nvj9
#                                                                val_loss: 0.624
# Epoch 1/4  ╸━━━━━━━━━━━━━━━━ 16/493 0:00:15 • 0:07:44 1.03it/s v_num: nvj9
#                                                                val_loss: 0.624
# Epoch 1/4  ╸━━━━━━━━━━━━━━━━ 17/493 0:00:16 • 0:07:43 1.03it/s v_num: nvj9
#                                                                val_loss: 0.624
# Epoch 1/4  ╸━━━━━━━━━━━━━━━━ 18/493 0:00:17 • 0:07:43 1.03it/s v_num: nvj9
#                                                                val_loss: 0.624
# Epoch 1/4  ╸━━━━━━━━━━━━━━━━ 19/493 0:00:18 • 0:07:42 1.03it/s v_num: nvj9
#                                                                val_loss: 0.624
# Epoch 1/4  ╸━━━━━━━━━━━━━━━━ 20/493 0:00:19 • 0:07:41 1.03it/s v_num: nvj9
#                                                                val_loss: 0.624
# Epoch 1/4  ╸━━━━━━━━━━━━━━━━ 21/493 0:00:20 • 0:07:40 1.03it/s v_num: nvj9
#                                                                val_loss: 0.624
# Epoch 1/4  ╸━━━━━━━━━━━━━━━━ 22/493 0:00:21 • 0:07:39 1.03it/s v_num: nvj9
#                                                                val_loss: 0.624
# Epoch 1/4  ╸━━━━━━━━━━━━━━━━ 23/493 0:00:22 • 0:07:39 1.03it/s v_num: nvj9
#                                                                val_loss: 0.624
# Epoch 1/4  ╸━━━━━━━━━━━━━━━━ 24/493 0:00:23 • 0:07:38 1.03it/s v_num: nvj9
#                                                                val_loss: 0.624
# Epoch 1/4  ╸━━━━━━━━━━━━━━━━ 25/493 0:00:24 • 0:07:37 1.03it/s v_num: nvj9
#                                                                val_loss: 0.624
# Epoch 1/4  ╸━━━━━━━━━━━━━━━━ 26/493 0:00:25 • 0:07:36 1.03it/s v_num: nvj9
#                                                                val_loss: 0.624
# Epoch 1/4  ╸━━━━━━━━━━━━━━━━ 27/493 0:00:26 • 0:07:35 1.03it/s v_num: nvj9
#                                                                val_loss: 0.624
# Epoch 1/4  ╸━━━━━━━━━━━━━━━━ 28/493 0:00:27 • 0:07:34 1.03it/s v_num: nvj9
#                                                                val_loss: 0.624
# Epoch 1/4  ━╺━━━━━━━━━━━━━━━ 29/493 0:00:28 • 0:07:33 1.03it/s v_num: nvj9
#                                                                val_loss: 0.624
# Epoch 1/4  ━╺━━━━━━━━━━━━━━━ 30/493 0:00:29 • 0:07:32 1.02it/s v_num: nvj9
#                                                                val_loss: 0.624
# Epoch 1/4  ━╺━━━━━━━━━━━━━━━ 31/493 0:00:30 • 0:07:32 1.02it/s v_num: nvj9
#                                                                val_loss: 0.624
# Epoch 1/4  ━╺━━━━━━━━━━━━━━━ 32/493 0:00:31 • 0:07:31 1.02it/s v_num: nvj9
#                                                                val_loss: 0.624
# Epoch 1/4  ━╺━━━━━━━━━━━━━━━ 33/493 0:00:32 • 0:07:30 1.02it/s v_num: nvj9
#                                                                val_loss: 0.624
# Epoch 1/4  ━╺━━━━━━━━━━━━━━━ 34/493 0:00:33 • 0:07:29 1.02it/s v_num: nvj9
#                                                                val_loss: 0.624
# Epoch 1/4  ━╺━━━━━━━━━━━━━━━ 35/493 0:00:34 • 0:07:28 1.02it/s v_num: nvj9
#                                                                val_loss: 0.624
# Epoch 1/4  ━╺━━━━━━━━━━━━━━━
/s v_num: nvj9
#                                                                val_loss: 0.580
# Epoch 4/4  ━━━━━━━━━━━━━━━╸ 480/493 0:07:48 • 0:00:13 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
# Epoch 4/4  ━━━━━━━━━━━━━━━╸ 481/493 0:07:49 • 0:00:12 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
# Epoch 4/4  ━━━━━━━━━━━━━━━╸ 482/493 0:07:49 • 0:00:11 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
# Epoch 4/4  ━━━━━━━━━━━━━━━╸ 483/493 0:07:50 • 0:00:10 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
# Epoch 4/4  ━━━━━━━━━━━━━━━╸ 484/493 0:07:51 • 0:00:09 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
# Epoch 4/4  ━━━━━━━━━━━━━━━╸ 485/493 0:07:52 • 0:00:08 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
# Epoch 4/4  ━━━━━━━━━━━━━━━╸ 486/493 0:07:53 • 0:00:07 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
# Epoch 4/4  ━━━━━━━━━━━━━━━╸ 487/493 0:07:54 • 0:00:06 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
# Epoch 4/4  ━━━━━━━━━━━━━━━╸ 488/493 0:07:55 • 0:00:05 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
# Epoch 4/4  ━━━━━━━━━━━━━━━╸ 489/493 0:07:56 • 0:00:04 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
# Epoch 4/4  ━━━━━━━━━━━━━━━╸ 490/493 0:07:57 • 0:00:03 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
# Epoch 4/4  ━━━━━━━━━━━━━━━╸ 491/493 0:07:58 • 0:00:02 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
# Epoch 4/4  ━━━━━━━━━━━━━━━╸ 492/493 0:07:59 • 0:00:01 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
# Epoch 4/4  ━━━━━━━━━━━━━━━━ 493/493 0:08:00 • 0:00:00 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
# Epoch 4/4  ━━━━━━━━━━━━━━━━ 493/493 0:08:00 • 0:00:00 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
# Epoch 4/4  ━━━━━━━━━━━━━━━━ 493/493 0:08:00 • 0:00:00 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
# Epoch 4/4  ━━━━━━━━━━━━━━━━ 493/493 0:08:00 • 0:00:00 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
#                                                                train_loss: 0.584
# Epoch 4/4  ━━━━━━━━━━━━━━━━ 493/493 0:08:00 • 0:00:00 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
#                                                                train_loss: 0.584
# Epoch 4/4  ━━━━━━━━━━━━━━━━ 493/493 0:08:00 • 0:00:00 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
#                                                                train_loss: 0.584
# Epoch 4/4  ━━━━━━━━━━━━━━━━ 493/493 0:08:00 • 0:00:00 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
#                                                                train_loss: 0.584
# Epoch 4/4  ━━━━━━━━━━━━━━━━ 493/493 0:08:00 • 0:00:00 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
#                                                                train_loss: 0.584
# Epoch 4/4  ━━━━━━━━━━━━━━━━ 493/493 0:08:00 • 0:00:00 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
#                                                                train_loss: 0.584
# Epoch 4/4  ━━━━━━━━━━━━━━━━ 493/493 0:08:00 • 0:00:00 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
#                                                                train_loss: 0.584
# Epoch 4/4  ━━━━━━━━━━━━━━━━ 493/493 0:08:00 • 0:00:00 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
#                                                                train_loss: 0.584
# Epoch 4/4  ━━━━━━━━━━━━━━━━ 493/493 0:08:00 • 0:00:00 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
#                                                                train_loss: 0.584
# Epoch 4/4  ━━━━━━━━━━━━━━━━ 493/493 0:08:00 • 0:00:00 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
#                                                                train_loss: 0.584
# Epoch 4/4  ━━━━━━━━━━━━━━━━ 493/493 0:08:00 • 0:00:00 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
#                                                                train_loss: 0.584
# Epoch 4/4  ━━━━━━━━━━━━━━━━ 493/493 0:08:00 • 0:00:00 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
#                                                                train_loss: 0.584
# Epoch 4/4  ━━━━━━━━━━━━━━━━ 493/493 0:08:00 • 0:00:00 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
#                                                                train_loss: 0.584
# Epoch 4/4  ━━━━━━━━━━━━━━━━ 493/493 0:08:00 • 0:00:00 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
#                                                                train_loss: 0.584
# Epoch 4/4  ━━━━━━━━━━━━━━━━ 493/493 0:08:00 • 0:00:00 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
#                                                                train_loss: 0.584
# Epoch 4/4  ━━━━━━━━━━━━━━━━ 493/493 0:08:00 • 0:00:00 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
#                                                                train_loss: 0.584
# Epoch 4/4  ━━━━━━━━━━━━━━━━ 493/493 0:08:00 • 0:00:00 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
#                                                                train_loss: 0.584
# Epoch 4/4  ━━━━━━━━━━━━━━━━ 493/493 0:08:00 • 0:00:00 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
#                                                                train_loss: 0.584
# Epoch 4/4  ━━━━━━━━━━━━━━━━ 493/493 0:08:00 • 0:00:00 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
#                                                                train_loss: 0.584
# Epoch 4/4  ━━━━━━━━━━━━━━━━ 493/493 0:08:00 • 0:00:00 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
#                                                                train_loss: 0.584
# Epoch 4/4  ━━━━━━━━━━━━━━━━ 493/493 0:08:00 • 0:00:00 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
#                                                                train_loss: 0.584
# Epoch 4/4  ━━━━━━━━━━━━━━━━ 493/493 0:08:00 • 0:00:00 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
#                                                                train_loss: 0.584
# Epoch 4/4  ━━━━━━━━━━━━━━━━ 493/493 0:08:00 • 0:00:00 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
#                                                                train_loss: 0.584
# Epoch 4/4  ━━━━━━━━━━━━━━━━ 493/493 0:08:00 • 0:00:00 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
#                                                                train_loss: 0.584
# Epoch 4/4  ━━━━━━━━━━━━━━━━ 493/493 0:08:00 • 0:00:00 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
#                                                                train_loss: 0.584
# Epoch 4/4  ━━━━━━━━━━━━━━━━ 493/493 0:08:00 • 0:00:00 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
#                                                                train_loss: 0.584
# Epoch 4/4  ━━━━━━━━━━━━━━━━ 493/493 0:08:00 • 0:00:00 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
#                                                                train_loss: 0.584
# Epoch 4/4  ━━━━━━━━━━━━━━━━ 493/493 0:08:00 • 0:00:00 1.03it/s v_num: nvj9
#                                                                val_loss: 0.580
# Epoch 4/4  ━━━━━━━━━━━━━━━━ 493/493 0:08:00 • 0:00:00 1.03it/s v_num: nvj9
#                                                                val_loss: 0.566
#                                                                train_loss: 0.574`Trainer.fit` stopped: `max_epochs=5` reached.
# Epoch 4/4  ━━━━━━━━━━━━━━━━ 493/493 0:08:00 • 0:00:00 1.03it/s v_num: nvj9
#                                                                val_loss: 0.566
#                                                                train_loss: 0.574
# wandb:
# wandb: 🚀 View run celestial-thunder-20 at: https://wandb.ai/models-university-of-cape-town/dlinknet_sentinel2_baseline/runs/q1y3nvj9

# %%
# %cd /kaggle/working/InstaRoadPrototype/

if is_yml:
    # !python -m src.utils.cli_main test    --config src/dlinknet/test.yaml
    # !python -m src.utils.cli_main predict --config src/dlinknet/predict.yaml
else:
    # %cd /kaggle/working/InstaRoadPrototype/src/dlinknet/
    # !python inference.py
# Out:
# /kaggle/working/InstaRoadPrototype
# /usr/local/lib/python3.12/dist-packages/lightning/fabric/utilities/seed.py:44: No seed found, seed set to 0
# Seed set to 0
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# [{'class_path': 'albumentations.Resize', 'init_args': {'height': 1024, 'width': 1024}}, {'class_path': 'albumentations.Normalize', 'init_args': {'mean': [0.485, 0.456, 0.406], 'std': [0.229, 0.224, 0.225]}}]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/2
# [rank: 1] Seed set to 0
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# [{'class_path': 'albumentations.Resize', 'init_args': {'height': 1024, 'width': 1024}}, {'class_path': 'albumentations.Normalize', 'init_args': {'mean': [0.485, 0.456, 0.406], 'std': [0.229, 0.224, 0.225]}}]
# Initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/2
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 2 processes
# ----------------------------------------------------------------------------------------------------
#
# Restoring states from the checkpoint path at /kaggle/working/checkpoints/dlinknet34_resnet34.ckpt
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/call.py:283: Be aware that when using `ckpt_path`, callbacks used to create the checkpoint need to be provided during `Trainer` instantiation. Please add the following callbacks: ["ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}"].
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1]
# Loaded model weights from the checkpoint at /kaggle/working/checkpoints/dlinknet34_resnet34.ckpt
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/connectors/data_connector.py:217: Using `DistributedSampler` with the dataloaders. During `trainer.test()`, it is recommended to use `Trainer(devices=1, num_nodes=1)` to ensure each sample/batch gets evaluated exactly once. Otherwise, multi-device settings use `DistributedSampler` that replicates some samples to make sure all devices have same batch size in case of uneven inputs.
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/connectors/log00 0.78it/s 0.77it/s
# ger_connector/result.py:433: It is recommended to use `self.log('test_iou', ...,
# sync_dist=True)` when logging on epoch level in distributed setting to
# accumulate the metric across devices.
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/connectors/log0m 0.78it/s
# ger_connector/result.py:433: It is recommended to use `self.log('test_f1', ...,
# sync_dist=True)` when logging on epoch level in distributed setting to
# accumulate the metric across devices.
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/connectors/log0m 0.78it/s
# ger_connector/result.py:433: It is recommended to use
# `self.log('test_precision', ..., sync_dist=True)` when logging on epoch level in
# distributed setting to accumulate the metric across devices.
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/connectors/log0m 0.78it/s
# ger_connector/result.py:433: It is recommended to use `self.log('test_recall',
# ..., sync_dist=True)` when logging on epoch level in distributed setting to
# accumulate the metric across devices.
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/connectors/log0m 0.78it/s
# ger_connector/result.py:433: It is recommended to use `self.log('test_accuracy',
# ..., sync_dist=True)` when logging on epoch level in distributed setting to
# accumulate the metric across devices.
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓0:00:35 • 0:00:00 0.78it/s
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │       test_accuracy       │    0.9908938407897949     │
# │          test_f1          │    0.4488663375377655     │
# │         test_iou          │    0.2893795371055603     │
# │      test_precision       │    0.37942132353782654    │
# │        test_recall        │     0.549427330493927     │
# └───────────────────────────┴───────────────────────────┘
# Testing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27/27 0:00:35 • 0:00:00 0.78it/s
# /usr/local/lib/python3.12/dist-packages/lightning/fabric/utilities/seed.py:44: No seed found, seed set to 0
# Seed set to 0
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# [{'class_path': 'albumentations.Resize', 'init_args': {'height': 1024, 'width': 1024}}, {'class_path': 'albumentations.Normalize', 'init_args': {'mean': [0.485, 0.456, 0.406], 'std': [0.229, 0.224, 0.225]}}]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/2
# [rank: 1] Seed set to 0
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# [{'class_path': 'albumentations.Resize', 'init_args': {'height': 1024, 'width': 1024}}, {'class_path': 'albumentations.Normalize', 'init_args': {'mean': [0.485, 0.456, 0.406], 'std': [0.229, 0.224, 0.225]}}]
# Initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/2
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 2 processes
# ----------------------------------------------------------------------------------------------------
#
# Restoring states from the checkpoint path at /kaggle/working/checkpoints/dlinknet34_resnet34.ckpt
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/call.py:283: Be aware that when using `ckpt_path`, callbacks used to create the checkpoint need to be provided during `Trainer` instantiation. Please add the following callbacks: ["ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}"].
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1]
# Loaded model weights from the checkpoint at /kaggle/working/checkpoints/dlinknet34_resnet34.ckpt
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# Predicting ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/27 0:00:00 • -:--:-- 0.00it/s Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.007835414..0.0102845915].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for
# floats or [0..255] for integers). Got range [-0.0074996348..0.010216242].
# Predicting ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/27 0:00:00 • -:--:-- 0.00it/s Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.006597804..0.0102845915].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for
# floats or [0..255] for integers). Got range [-0.0069395527..0.0102845915].
# Predicting ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/27 0:00:00 • -:--:-- 0.00it/s Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.00790257..0.0102845915].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for
# floats or [0..255] for integers). Got range [-0.006802853..0.0102845915].
# Predicting ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/27 0:00:00 • -:--:-- 0.00it/s Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.0070295436..0.0102845915].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for
# floats or [0..255] for integers). Got range [-0.007007903..0.0102845915].
# Predicting ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/27 0:00:00 • -:--:-- 0.00it/s Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.008171193..0.01035294].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for
# floats or [0..255] for integers). Got range [-0.0077682585..0.0102845915].
# Predicting ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/27 0:00:00 • -:--:-- 0.00it/s Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.008171193..0.010216242].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for
# floats or [0..255] for integers). Got range [-0.007835414..0.0102845915].
# Predicting ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/27 0:00:00 • -:--:-- 0.00it/s Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.007835414..0.0102845915].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for
# floats or [0..255] for integers). Got range [-0.0068712034..0.010216242].
# Predicting ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/27 0:00:00 • -:--:-- 0.00it/s Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.008036882..0.010216242].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for
# floats or [0..255] for integers). Got range [-0.0067345034..0.0102845915].
# Predicting ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/27 0:00:00 • -:--:-- 0.00it/s Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.006529454..0.010216242].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for
# floats or [0..255] for integers). Got range [-0.006802853..0.0102845915].
# Predicting ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/27 0:00:00 • -:--:-- 0.00it/s Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.007835414..0.0102845915].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for
# floats or [0..255] for integers). Got range [-0.00790257..0.010216242].
# Predicting ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/27 0:00:00 • -:--:-- 0.00it/s Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.008036882..0.0102845915].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for
# floats or [0..255] for integers). Got range [-0.008171193..0